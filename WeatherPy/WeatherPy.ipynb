# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# # Output File (CSV)
output_data_file = "output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists to store data from API calls
new_cities = []
lat = []
lng = []
max_temp = []
wind_speed = []
humidity = []
cloudiness = []
country = []
datetime = []

counter = 0

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    counter += 1
    
    try:
        new_cities.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        datetime.append(response['dt'])
        print(f"Processing record {counter} | {city}")
    
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing record 1 | qinhuangdao
# Processing record 2 | jamestown
# Processing record 3 | puerto ayora
# City not found. Skipping...
# Processing record 5 | hithadhoo
# Processing record 6 | camacha
# Processing record 7 | cidreira
# Processing record 8 | muscat
# Processing record 9 | pindiga
# Processing record 10 | east london
# Processing record 11 | rikitea
# Processing record 12 | maryville
# Processing record 13 | kapaa
# Processing record 14 | mataura
# Processing record 15 | teguldet
# Processing record 16 | bouca
# Processing record 17 | carnarvon
# City not found. Skipping...
# Processing record 19 | paita
# Processing record 20 | ostrovnoy
# Processing record 21 | upernavik
# Processing record 22 | hauterive
# Processing record 23 | saskylakh
# Processing record 24 | dingle
# Processing record 25 | punta arenas
# Processing record 26 | buritis
# Processing record 27 | torbay
# Processing record 28 | bluff
# Processing record 29 | chicama
# Processing record 30 | sept-iles
# Processing record 31 | khatanga
# Processing record 32 | coahuayana
# Processing record 33 | busselton
# Processing record 34 | kruisfontein
# Processing record 35 | rocha
# Processing record 36 | tavatuy
# Processing record 37 | dalmatovo
# Processing record 38 | severo-kurilsk
# Processing record 39 | gaoua
# Processing record 40 | katobu
# Processing record 41 | ushuaia
# Processing record 42 | atuona
# Processing record 43 | los llanos de aridane
# Processing record 44 | paamiut
# Processing record 45 | el tigre
# Processing record 46 | arrifes
# Processing record 47 | natal
# Processing record 48 | cape town
# Processing record 49 | butaritari
# Processing record 50 | ilulissat
# Processing record 51 | lubu
# Processing record 52 | kavieng
# City not found. Skipping...
# Processing record 54 | asau
# Processing record 55 | castro
# Processing record 56 | zhigansk
# Processing record 57 | natitingou
# Processing record 58 | xuddur
# Processing record 59 | sao miguel do tapuio
# Processing record 60 | vaini
# Processing record 61 | jintur
# City not found. Skipping...
# Processing record 63 | port hardy
# Processing record 64 | mar del plata
# Processing record 65 | proletariy
# Processing record 66 | dukat
# Processing record 67 | mount gambier
# Processing record 68 | bandar-e anzali
# Processing record 69 | hobart
# Processing record 70 | gorom-gorom
# Processing record 71 | lucea
# Processing record 72 | port alfred
# Processing record 73 | albany
# Processing record 74 | zuenoula
# Processing record 75 | bethel
# Processing record 76 | dikson
# Processing record 77 | fortuna
# Processing record 78 | saint-joseph
# Processing record 79 | senador guiomard
# Processing record 80 | ugoofaaru
# Processing record 81 | washougal
# Processing record 82 | jati
# Processing record 83 | geraldton
# Processing record 84 | ponta delgada
# Processing record 85 | kargasok
# Processing record 86 | cayenne
# Processing record 87 | general roca
# Processing record 88 | nikolskoye
# Processing record 89 | bahia honda
# Processing record 90 | cherskiy
# Processing record 91 | doha
# Processing record 92 | ola
# Processing record 93 | namatanai
# City not found. Skipping...
# Processing record 95 | moshupa
# Processing record 96 | mocuba
# Processing record 97 | omboue
# Processing record 98 | cabedelo
# Processing record 99 | port blair
# Processing record 100 | ondjiva
# Processing record 101 | salalah
# Processing record 102 | provideniya
# Processing record 103 | progreso
# Processing record 104 | kaitangata
# Processing record 105 | lamu
# Processing record 106 | akdepe
# Processing record 107 | puerto montt
# Processing record 108 | centralina
# Processing record 109 | boma
# Processing record 110 | hearst
# Processing record 111 | chokurdakh
# Processing record 112 | cabo san lucas
# Processing record 113 | cockburn town
# Processing record 114 | weiser
# Processing record 115 | hovd
# Processing record 116 | arraial do cabo
# Processing record 117 | lima
# Processing record 118 | ribeira grande
# Processing record 119 | chamba
# Processing record 120 | klaksvik
# Processing record 121 | estevan
# Processing record 122 | qaanaaq
# Processing record 123 | tuktoyaktuk
# Processing record 124 | kodiak
# Processing record 125 | kontagora
# City not found. Skipping...
# Processing record 127 | pevek
# Processing record 128 | grand-santi
# City not found. Skipping...
# City not found. Skipping...
# Processing record 131 | assiniboia
# Processing record 132 | urumqi
# Processing record 133 | avarua
# Processing record 134 | hermanus
# Processing record 135 | taltal
# Processing record 136 | ghanzi
# Processing record 137 | esperance
# Processing record 138 | new norfolk
# Processing record 139 | georgetown
# Processing record 140 | saint george
# Processing record 141 | shimoda
# Processing record 142 | coquimbo
# Processing record 143 | pamanukan
# City not found. Skipping...
# Processing record 145 | slave lake
# Processing record 146 | vanimo
# Processing record 147 | labuan
# Processing record 148 | pankovka
# Processing record 149 | palkino
# Processing record 150 | saint-philippe
# Processing record 151 | port-cartier
# City not found. Skipping...
# Processing record 153 | chapais
# City not found. Skipping...
# Processing record 155 | northam
# Processing record 156 | port elizabeth
# Processing record 157 | fuerte olimpo
# Processing record 158 | barrow
# Processing record 159 | churapcha
# Processing record 160 | sisimiut
# Processing record 161 | souillac
# Processing record 162 | yellowknife
# Processing record 163 | chuy
# City not found. Skipping...
# Processing record 165 | pangnirtung
# Processing record 166 | clyde river
# Processing record 167 | olinda
# Processing record 168 | hilo
# Processing record 169 | henties bay
# Processing record 170 | genhe
# Processing record 171 | lorengau
# Processing record 172 | hualmay
# Processing record 173 | saint-pierre
# Processing record 174 | banda aceh
# Processing record 175 | mao
# Processing record 176 | hasaki
# Processing record 177 | marsala
# Processing record 178 | mwinilunga
# Processing record 179 | tamandare
# Processing record 180 | codrington
# City not found. Skipping...
# Processing record 182 | halifax
# Processing record 183 | canico
# Processing record 184 | san jeronimo
# Processing record 185 | ponta do sol
# Processing record 186 | plon
# Processing record 187 | padang
# Processing record 188 | lompoc
# City not found. Skipping...
# Processing record 190 | luderitz
# Processing record 191 | yuli
# Processing record 192 | honningsvag
# Processing record 193 | maarianhamina
# Processing record 194 | hamilton
# Processing record 195 | baculin
# Processing record 196 | syracuse
# Processing record 197 | okha
# Processing record 198 | nhulunbuy
# Processing record 199 | ngunguru
# Processing record 200 | harrisonburg
# City not found. Skipping...
# Processing record 202 | bambanglipuro
# Processing record 203 | bredasdorp
# City not found. Skipping...
# Processing record 205 | longyearbyen
# Processing record 206 | dhidhdhoo
# City not found. Skipping...
# Processing record 208 | cuamba
# City not found. Skipping...
# Processing record 210 | oktyabrskoye
# City not found. Skipping...
# Processing record 212 | stokmarknes
# Processing record 213 | saryozek
# Processing record 214 | bathsheba
# Processing record 215 | kimbe
# Processing record 216 | katsuura
# City not found. Skipping...
# Processing record 218 | humaita
# Processing record 219 | bengkulu
# Processing record 220 | calvia
# Processing record 221 | adrar
# Processing record 222 | oranjemund
# Processing record 223 | maltahohe
# Processing record 224 | ahipara
# Processing record 225 | baykit
# Processing record 226 | shingu
# Processing record 227 | charters towers
# Processing record 228 | wenling
# Processing record 229 | gobabis
# Processing record 230 | tasiilaq
# Processing record 231 | ludza
# City not found. Skipping...
# Processing record 233 | palmer
# Processing record 234 | chifeng
# Processing record 235 | college
# Processing record 236 | porto santo
# Processing record 237 | flin flon
# Processing record 238 | rio gallegos
# Processing record 239 | kansanshi
# Processing record 240 | abu dhabi
# Processing record 241 | kahului
# Processing record 242 | kimparana
# Processing record 243 | mahebourg
# Processing record 244 | raudeberg
# Processing record 245 | mantua
# Processing record 246 | san cristobal
# Processing record 247 | te anau
# Processing record 248 | berlevag
# Processing record 249 | sayat
# City not found. Skipping...
# Processing record 251 | manicore
# Processing record 252 | cubuk
# Processing record 253 | birao
# Processing record 254 | boden
# Processing record 255 | ballina
# Processing record 256 | sao filipe
# Processing record 257 | arcachon
# Processing record 258 | hobyo
# Processing record 259 | qarqin
# Processing record 260 | bonthe
# Processing record 261 | lianran
# Processing record 262 | tiksi
# Processing record 263 | santa cruz
# Processing record 264 | medgyesegyhaza
# City not found. Skipping...
# Processing record 266 | sagua la grande
# Processing record 267 | anito
# Processing record 268 | harper
# Processing record 269 | saint-prosper
# Processing record 270 | taft
# Processing record 271 | lata
# Processing record 272 | thompson
# Processing record 273 | vaitape
# Processing record 274 | hami
# Processing record 275 | mormugao
# Processing record 276 | touho
# Processing record 277 | dvorichna
# Processing record 278 | odweyne
# Processing record 279 | celestun
# Processing record 280 | yarmouth
# Processing record 281 | iqaluit
# Processing record 282 | poum
# Processing record 283 | touros
# Processing record 284 | itaituba
# Processing record 285 | qaqortoq
# Processing record 286 | chumikan
# Processing record 287 | bosaso
# Processing record 288 | nuuk
# City not found. Skipping...
# Processing record 290 | port keats
# City not found. Skipping...
# City not found. Skipping...
# Processing record 293 | cubarral
# Processing record 294 | norman wells
# Processing record 295 | barcelos
# Processing record 296 | lasa
# Processing record 297 | tual
# Processing record 298 | la ronge
# City not found. Skipping...
# Processing record 300 | kailua
# City not found. Skipping...
# Processing record 302 | san patricio
# Processing record 303 | gudur
# Processing record 304 | malinovoye ozero
# Processing record 305 | meulaboh
# Processing record 306 | lebu
# Processing record 307 | juba
# Processing record 308 | wanganui
# Processing record 309 | monrovia
# Processing record 310 | buala
# Processing record 311 | naze
# Processing record 312 | olafsvik
# Processing record 313 | paris
# Processing record 314 | dzaoudzi
# Processing record 315 | newport
# Processing record 316 | broken hill
# Processing record 317 | alugan
# Processing record 318 | ciudad bolivar
# Processing record 319 | santa cruz de tenerife
# Processing record 320 | comodoro rivadavia
# City not found. Skipping...
# Processing record 322 | avera
# Processing record 323 | canto do buriti
# Processing record 324 | tall kayf
# Processing record 325 | villa del rosario
# Processing record 326 | kamenka
# Processing record 327 | kragujevac
# Processing record 328 | amboasary
# Processing record 329 | flinders
# Processing record 330 | san andres
# City not found. Skipping...
# Processing record 332 | noumea
# Processing record 333 | xining
# Processing record 334 | tautira
# Processing record 335 | yeppoon
# Processing record 336 | lodja
# City not found. Skipping...
# Processing record 338 | tarabuco
# Processing record 339 | yunhe
# Processing record 340 | sidney
# Processing record 341 | siyabuswa
# Processing record 342 | ulladulla
# Processing record 343 | pathein
# City not found. Skipping...
# Processing record 345 | uthai thani
# Processing record 346 | tabou
# Processing record 347 | hrob
# Processing record 348 | cozumel
# Processing record 349 | mayo
# Processing record 350 | kununurra
# Processing record 351 | valleyview
# City not found. Skipping...
# Processing record 353 | prince rupert
# Processing record 354 | axim
# Processing record 355 | hoquiam
# Processing record 356 | makakilo city
# Processing record 357 | narsaq
# Processing record 358 | price
# Processing record 359 | jatai
# Processing record 360 | saurimo
# Processing record 361 | kurdzhinovo
# Processing record 362 | mezen
# Processing record 363 | ferme-neuve
# Processing record 364 | shache
# Processing record 365 | deputatskiy
# Processing record 366 | sokolo
# Processing record 367 | itoman
# City not found. Skipping...
# Processing record 369 | covington
# Processing record 370 | westport
# Processing record 371 | pierre
# Processing record 372 | miyang
# Processing record 373 | xai-xai
# Processing record 374 | yulara
# Processing record 375 | wilmington
# Processing record 376 | gornopravdinsk
# Processing record 377 | graaff-reinet
# Processing record 378 | zapolyarnyy
# Processing record 379 | port lincoln
# Processing record 380 | evensk
# Processing record 381 | pascagoula
# Processing record 382 | atambua
# Processing record 383 | gazojak
# Processing record 384 | srednekolymsk
# Processing record 385 | phan thiet
# Processing record 386 | lake wales
# Processing record 387 | shimanovsk
# Processing record 388 | cap malheureux
# Processing record 389 | desaguadero
# Processing record 390 | almaznyy
# Processing record 391 | ribeira brava
# Processing record 392 | fayetteville
# Processing record 393 | bat khela
# Processing record 394 | hervey bay
# Processing record 395 | panzhihua
# Processing record 396 | aklavik
# Processing record 397 | verkhnevilyuysk
# Processing record 398 | mandiana
# City not found. Skipping...
# Processing record 400 | kutum
# Processing record 401 | rock sound
# Processing record 402 | petawawa
# Processing record 403 | ust-kuyga
# Processing record 404 | tukrah
# Processing record 405 | plerin
# Processing record 406 | shenjiamen
# Processing record 407 | xiuyan
# Processing record 408 | mbanza-ngungu
# Processing record 409 | sitka
# Processing record 410 | oudtshoorn
# City not found. Skipping...
# Processing record 412 | perth
# Processing record 413 | eyl
# Processing record 414 | esso
# Processing record 415 | viedma
# Processing record 416 | muzaffarpur
# Processing record 417 | evanston
# Processing record 418 | krasnogorskiy
# Processing record 419 | gilbues
# Processing record 420 | ekhabi
# Processing record 421 | vardo
# Processing record 422 | manono
# Processing record 423 | tricase
# Processing record 424 | vila velha
# Processing record 425 | narodychi
# Processing record 426 | lavrentiya
# Processing record 427 | poco branco
# Processing record 428 | alta floresta
# Processing record 429 | karangampel
# Processing record 430 | dunedin
# Processing record 431 | fuxin
# Processing record 432 | quatre cocos
# City not found. Skipping...
# Processing record 434 | ulagan
# Processing record 435 | belmonte
# Processing record 436 | iskateley
# Processing record 437 | matagami
# Processing record 438 | aflao
# City not found. Skipping...
# City not found. Skipping...
# Processing record 441 | malakal
# Processing record 442 | trincomalee
# Processing record 443 | victoria
# Processing record 444 | harqalah
# Processing record 445 | ippy
# Processing record 446 | konstantinovka
# Processing record 447 | cantaura
# Processing record 448 | saint-paul
# Processing record 449 | atbasar
# Processing record 450 | rawson
# Processing record 451 | puerto del rosario
# Processing record 452 | zaysan
# Processing record 453 | asyut
# Processing record 454 | arlit
# Processing record 455 | portachuelo
# Processing record 456 | laguna
# Processing record 457 | warmbad
# Processing record 458 | elat
# Processing record 459 | muros
# Processing record 460 | riverton
# Processing record 461 | sorong
# Processing record 462 | raga
# Processing record 463 | basar
# Processing record 464 | ixtapa
# Processing record 465 | palpa
# Processing record 466 | hambantota
# Processing record 467 | jumla
# Processing record 468 | bemidji
# City not found. Skipping...
# Processing record 470 | zajecar
# Processing record 471 | christchurch
# Processing record 472 | salisbury
# Processing record 473 | skjervoy
# Processing record 474 | san carlos de bariloche
# Processing record 475 | gazli
# City not found. Skipping...
# Processing record 477 | gohpur
# Processing record 478 | galveston
# Processing record 479 | tessalit
# Processing record 480 | calafell
# Processing record 481 | ust-kulom
# City not found. Skipping...
# Processing record 483 | volcan
# City not found. Skipping...
# Processing record 485 | mezhova
# Processing record 486 | airai
# Processing record 487 | neiafu
# Processing record 488 | yenagoa
# Processing record 489 | fairview
# Processing record 490 | alice springs
# Processing record 491 | ketchikan
# Processing record 492 | inta
# Processing record 493 | pisco
# Processing record 494 | severomuysk
# Processing record 495 | isangel
# Processing record 496 | benjamin constant
# Processing record 497 | tygda
# Processing record 498 | dakar
# Processing record 499 | bambous virieux
# Processing record 500 | ufimskiy
# Processing record 501 | apache junction
# Processing record 502 | mecca
# Processing record 503 | morros
# Processing record 504 | havoysund
# Processing record 505 | mongomo
# Processing record 506 | coruripe
# Processing record 507 | le vauclin
# Processing record 508 | moose factory
# Processing record 509 | margate
# Processing record 510 | mandal
# Processing record 511 | nantucket
# Processing record 512 | reinosa
# City not found. Skipping...
# Processing record 514 | komsomolskiy
# Processing record 515 | khandagayty
# Processing record 516 | kloulklubed
# Processing record 517 | biak
# City not found. Skipping...
# Processing record 519 | magadan
# Processing record 520 | dongsheng
# City not found. Skipping...
# City not found. Skipping...
# Processing record 523 | bonfim
# Processing record 524 | acoyapa
# Processing record 525 | kushmurun
# Processing record 526 | radeberg
# Processing record 527 | tongliao
# Processing record 528 | trofors
# Processing record 529 | coihaique
# Processing record 530 | barrington
# Processing record 531 | krasnovishersk
# Processing record 532 | havre-saint-pierre
# Processing record 533 | rakkestad
# Processing record 534 | inirida
# Processing record 535 | pangai
# Processing record 536 | tuatapere
# Processing record 537 | watsa
# Processing record 538 | lavumisa
# Processing record 539 | oltu
# Processing record 540 | tura
# Processing record 541 | sinnamary
# Processing record 542 | baker city
# City not found. Skipping...
# Processing record 544 | tandil
# Processing record 545 | kingsport
# Processing record 546 | itarema
# Processing record 547 | sao joao da barra
# Processing record 548 | colesberg
# Processing record 549 | morondava
# Processing record 550 | grootfontein
# Processing record 551 | sur
# Processing record 552 | puerto baquerizo moreno
# City not found. Skipping...
# Processing record 554 | okhotsk
# Processing record 555 | ginda
# Processing record 556 | olga
# Processing record 557 | richards bay
# Processing record 558 | beringovskiy
# Processing record 559 | pacific grove
# Processing record 560 | sorland
# Processing record 561 | portree
# Processing record 562 | liberty
# Processing record 563 | kosonsoy
# Processing record 564 | caravelas
# Processing record 565 | el sauzal
# Processing record 566 | sayan
# Processing record 567 | rupert
# Processing record 568 | basoko
# Processing record 569 | samarai
# Processing record 570 | iwaki
# Processing record 571 | sawakin
# Processing record 572 | alzamay
# Processing record 573 | mweka
# City not found. Skipping...
# Processing record 575 | beyneu
# Processing record 576 | roura
# Processing record 577 | balkanabat
# Processing record 578 | dzhebariki-khaya
# Processing record 579 | taoudenni
# Processing record 580 | shalya
# Processing record 581 | buguruslan
# Processing record 582 | ambatondrazaka
# Processing record 583 | manavgat
# Processing record 584 | kampong thum
# Processing record 585 | valparaiso
# Processing record 586 | mangaratiba
# Processing record 587 | moindou
# Processing record 588 | yerbogachen
# Processing record 589 | aykhal
# Processing record 590 | yumen
# City not found. Skipping...
# Processing record 592 | sidi bin nur
# Processing record 593 | najran
# Processing record 594 | tulun
# Processing record 595 | haines junction
# City not found. Skipping...
# Processing record 597 | belyy yar
# Processing record 598 | constitucion
# Processing record 599 | pontianak
# Processing record 600 | chiang klang
# Processing record 601 | pathalgaon
# Processing record 602 | bealanana
# Processing record 603 | lexington
# Processing record 604 | lagoa
# Processing record 605 | yen bai
# City not found. Skipping...
# Processing record 607 | griffith
# Processing record 608 | kaeo
# Processing record 609 | suixi
# Processing record 610 | sembakung
# Processing record 611 | kaduqli
# Processing record 612 | saint-georges
# Processing record 613 | raichur
# Processing record 614 | faanui

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dataframe to store results
weather_data = pd.DataFrame({
    'City':new_cities,
    'Lat':lat,
    'Lng':lng,
    'Max Temp':max_temp,
    'Humidity':humidity,
    'Cloudiness':cloudiness,
    'Wind Speed': wind_speed,
    'Country': country,
    'Date': datetime
})

# %%
# Visualize to confirm data appears
weather_data.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Qinhuangdao  39.9317  119.5883     60.49        19           0
# 1     Jamestown  42.0970  -79.2353     60.80        82          90
# 2  Puerto Ayora  -0.7393  -90.3518     80.60        74          20
# 3     Hithadhoo  -0.6000   73.0833     83.53        67          28
# 4       Camacha  33.0833  -16.3333     62.60        59          75
#
#    Wind Speed Country        Date
# 0       16.89      CN  1620171751
# 1        5.75      US  1620171298
# 2       18.41      EC  1620171302
# 3        3.36      MV  1620171038
# 4       12.66      PT  1620171331

# %%
# Save Data to csv
weather_data.to_csv(output_data_file)

# %%
weather_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  559.000000  559.000000  559.000000  559.000000  559.000000  559.000000
# mean    20.493596   12.893960   61.979106   70.869410   53.715564    7.872791
# std     33.244801   93.720039   17.778270   21.265916   36.627148    5.478897
# min    -54.800000 -179.166700   10.620000    6.000000    0.000000    0.380000
# 25%     -7.003300  -70.675000   47.785000   61.000000   20.000000    3.530000
# 50%     25.519800   18.957000   64.400000   75.000000   62.000000    6.350000
# 75%     49.841750   96.701650   77.000000   87.000000   90.000000   11.225000
# max     78.218600  179.316700   91.990000  100.000000  100.000000   36.820000
#
#                Date
# count  5.590000e+02
# mean   1.620171e+09
# std    1.035761e+02
# min    1.620171e+09
# 25%    1.620171e+09
# 50%    1.620171e+09
# 75%    1.620171e+09
# max    1.620171e+09

# %% [markdown]
# Inspect the data and remove the cities where the humidity > 100%

# %%
# Skipping as no cities have humidity greater than 100%

# %% [markdown]
# # Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels
# * Save the plotted figures as .pngs

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data['Lat'],weather_data['Max Temp'],marker='o',edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title ('City Latitude vs. Max Temperature (3/26/21)')
plt.grid(True)

plt.savefig('output/Latitude_vs_MaxTemp.png',bbox_inches='tight',facecolor='w')

plt.show()

# Plotting relationship between latitude and max temperature.
# Max temperature is the highest for cities near the equator or slightly north and the lowest temperatures are very far north though cities have more extreme north latitude points

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data['Lat'],weather_data['Humidity'],marker='x',edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title ('City Latitude vs. Humidity (3/26/21)')
plt.grid(True)

plt.savefig('output/Latitude_vs_Humidity.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting relationship between latitude and humidity.
# There is no significant trend between latitude and humidity. Cities near latitude of 20 generally seems to have lower humidity and near the equator tends to have higher humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data['Lat'],weather_data['Cloudiness'],marker='*',color='yellow',edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title ('City Latitude vs. Cloudiness (3/26/21)')
plt.grid(True)

plt.savefig('output/Latitude_vs_Cloudiness.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting relationship between latitude and cloudiness.
# There is no significant trend between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data['Lat'],weather_data['Wind Speed'],marker='D',color="red",edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title ('City Latitude vs. Wind Speed (3/26/21)')
plt.grid(True)

plt.savefig('output/Latitude_vs_Wind_Speed.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting relationship between latitude and wind speed.
# There is no significant trend between latitude and wind speed, not enough data points on the extremes where wind speed seems to increase slightly in the southern hemisphere to draw a conclusion

# %% [markdown]
# ## Linear Regression

# %%
# Split data into northern and souther hemisphere based on latitude
northern_df = weather_data.loc[weather_data['Lat'] >=0,:]
southern_df = weather_data.loc[weather_data['Lat'] < 0,:]

# %%
# Quick check on northern hemisphere
northern_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Qinhuangdao  39.9317  119.5883     60.49        19           0       16.89
# 1    Jamestown  42.0970  -79.2353     60.80        82          90        5.75
# 4      Camacha  33.0833  -16.3333     62.60        59          75       12.66
# 6       Muscat  23.6139   58.5922     80.60        69          20       18.41
# 7      Pindiga   9.9833   10.9333     79.95        59          66       13.38
#
#   Country        Date
# 0      CN  1620171751
# 1      US  1620171298
# 4      PT  1620171331
# 6      OM  1620171547
# 7      NG  1620171752

# %%
# Quick check on southern hemisphere
southern_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2  Puerto Ayora  -0.7393  -90.3518     80.60        74          20
# 3     Hithadhoo  -0.6000   73.0833     83.53        67          28
# 5      Cidreira -30.1811  -50.2056     66.54        92          97
# 8   East London -33.0153   27.9116     66.34        59           4
# 9       Rikitea -23.1203 -134.9692     78.51        79          99
#
#    Wind Speed Country        Date
# 2       18.41      EC  1620171302
# 3        3.36      MV  1620171038
# 5       14.88      BR  1620171290
# 8        3.42      ZA  1620171283
# 9       10.38      PF  1620171270

# %% [markdown]
# ### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values, marker='o', color='blue')
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere: Latitude vs. Max Temp (3/26/21)')
plt.annotate(line_eq,(10,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save plot as png
plt.savefig('output/northernhemi_maxtemp.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting max temperature trend in northern hemisphere.
# Max temperature decreases as you increase in latitude with few outliers
# Out:
# The r-value is: 0.7812306556905557

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values, marker='o',color='Blue')
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere: Latitude vs. Max Temp (3/26/21)')
plt.annotate(line_eq,(-30,55),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save plot as png
plt.savefig('output/southernhem_maxtemp.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting max temperature trend in southern hemisphere.
# Max temperature decreases as you decrease in latitude but more outliers than northern hemisphere
# Out:
# The r-value is: 0.5511757389733033

# %% [markdown]
# ### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values,color='Blue')
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere: Latitude vs. Humidity (3/26/21)')
plt.annotate(line_eq,(30,30),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save plot as png
plt.savefig('output/northernhem_humidity.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting humidity trend in northern hemisphere.
# There is no significant trend observed.
# Out:
# The r-value is: 0.0010248568943100474

# %% [markdown]
# ### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values,color='Blue')
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere: Latitude vs. Humidity (3/26/21)')
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save plot as png
plt.savefig('output/southernhem_humidity.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting humidity trend in souther hemisphere.
# There is no significant trend observed.
# Out:
# The r-value is: 0.04764238473281958

# %% [markdown]
# ### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values,color='Blue')
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere: Latitude vs. Cloudiness (3/26/21)')
plt.annotate(line_eq,(30,60),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save plot as png
plt.savefig('output/northernhem_cloudiness.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting cloudiness trend in northern hemisphere.
# There is no significant trend observed.
# Out:
# The r-value is: 7.674529081363088e-05

# %% [markdown]
# ### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values,color='Blue')
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere: Latitude vs. Cloudiness (3/26/21)')
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save plot as png
plt.savefig('output/southernhem_cloudiness.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting cloudiness trend in southern hemisphere.
# There is no significant trend observed.
# Out:
# The r-value is: 0.06338400126702068

# %% [markdown]
# ### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values,color='Blue')
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere: Latitude vs. Wind Speed (3/26/21)')
plt.annotate(line_eq,(30,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save plot as png
plt.savefig('output/northernhem_windspeed.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting wind speed trend in northern hemisphere.
# There is no significant trend observed.
# Out:
# The r-value is: 0.02013309984579132

# %% [markdown]
# ### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values,color='Blue')
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere: Latitude vs. Wind Speed (3/26/21)')
plt.annotate(line_eq,(-30,12),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save plot as png
plt.savefig('output/southernhem_windspeed.png',bbox_inches='tight',facecolor='w')

plt.show()
# Plotting wind speed trend in southern hemisphere.
# There is no significant trend observed.
# Out:
# The r-value is: 0.05403929130129009
